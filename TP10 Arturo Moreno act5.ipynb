# %% [markdown]
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# Parte 1 – Análisis básico del dataset (10 puntos)

# %% [markdown]
# 1. Carga y exploración inicial
# Cargue el dataset y muestre sus primeras filas. Indique el número de filas y columnas.

# %% [markdown]
# Resp: aqui esta el codigo para mostrar las filas y columnas

# %%
area = pd.read_csv("area_protegida.csv")

# %%
print("Primeras 10 filas:")
print(area.head())
# Out:
# Primeras 10 filas:
#          lat        lng  gid entidad          objeto  \
# 0 -53.546655 -68.041297  362   falso  Área protegida
# 1 -31.404445 -64.357709  157   falso  Área protegida
# 2 -32.245004 -60.734423  169   falso  Área protegida
# 3 -26.031780 -54.418743   47   falso  Área protegida
# 4 -26.402258 -65.680992  206   falso  Área protegida
#
#                                                  fna  \
# 0  Sitio RAMSAR y Reserva Hemisférica Costa Atlán...
# 1            Reserva Natural de la Defensa La Calera
# 2                      Sitio Ramsar Delta del Parana
# 3   Parque Natural Municipal Lote C Huerto Municipal
# 4              Parque Provincial Cumbres Calchaquíes
#
#                                   gna                                  nam  \
# 0  Sitio RAMSAR y Reserva Hemisférica  Costa Atlántica de Tierra del Fuego
# 1       Reserva Natural de la Defensa                            La Calera
# 2                        Sitio Ramsar                     Delta del Parana
# 3            Parque Natural Municipal              Lote C Huerto Municipal
# 4                   Parque Provincial                  Cumbres Calchaquíes
#
#    tap  jap  caa                                     fdc    sag     area
# 0    2    2   17      SIB/IGN/Ley Provincial Nº 415/1998    IGN   762166
# 1    2    2   17  SIB/IGN/Protocolo adicional Nº 05/2009    IGN   136225
# 2    2    2   17                                     NaN  MAyDS  2430979
# 3    1    4   17            SIB/IGN/Disposición Nº 45/95    IGN      955
# 4    1    3   17                                     NaN    IGN   706222

# %% [markdown]
# utilizamos shape para saber el numero de filas y columnas:

# %%
print(area.shape)
# Out:
# (395, 14)

# %% [markdown]
# 2. Estructura y tipos de datos
# Identifique el tipo de dato de cada columna (numérico, categórico, fecha, geográfico, etc.) y presente un resumen de los tipos.

# %% [markdown]
# esto se puede entender con mejor facilidad utilizando Dtypes

# %%
print("Primeras 10 filas:")
print(area.dtypes)
# Out:
# Primeras 10 filas:
# lat        float64
# lng        float64
# gid          int64
# entidad        str
# objeto         str
# fna            str
# gna            str
# nam            str
# tap          int64
# jap          int64
# caa          int64
# fdc            str
# sag            str
# area         int64
# dtype: object

# %% [markdown]
# resumiendo los tipos:

# %% [markdown]
# lat ing: corresponden a un tipo de dato geografico

# %% [markdown]
# gid: es un identificador de grupo numerico

# %% [markdown]
# entidad: reconoce un lugar como parte del dataset

# %% [markdown]
# objeto: identifica una zona como parte de las areas protegidas

# %% [markdown]
# fna: es la firma de nombre geografico (nombre completo)

# %% [markdown]
# gna: significa genero del nombre geografico (termino generico)

# %% [markdown]
# nam: nombre geografico generico (termino especifico)

# %% [markdown]
# tap: tipo de area

# %% [markdown]
# jap: jurisdiccion

# %% [markdown]
# caa: Clasificación de acuerdo al tipo de autoridad responsable

# %% [markdown]
# fdp: fuente de captura

# %% [markdown]
# sad: Nombre de la autoridad responsable de la información utilizada

# %%
area: identificador de area por cordenada

# %% [markdown]
# 3. Estadísticas descriptivas
# Calcule y comente las principales medidas de resumen (media, mediana, mínimo, máximo, desviación estándar) para las variables numéricas.

# %% [markdown]
# resp: calculo y resumen numerico de longitud (lng)

# %% [markdown]
# con max se calcula el valor maximo

# %%
print(area["lng"].max())
# Out:
# -53.7909397257891

# %% [markdown]
# con min se calcula el valor minimo

# %%
print(area["lng"].min())
# Out:
# -73.402908018618

# %% [markdown]
# con mean se calcula el promedio

# %%
print(area["lng"].mean())
# Out:
# -63.44387137479367

# %% [markdown]
# con std se puede calcula la desviacion estandar

# %%
area["lng"].std()
# Out:
# np.float64(5.700540091735373)

# %% [markdown]
# 4. Valores nulos
# Detecte la cantidad de valores faltantes por columna y proponga una estrategia para tratarlos (eliminación, imputación, etc.). Justifique su decisión.

# %% [markdown]
# resp. asi se obtienen los valores nulos

# %%
print(area.isnull().sum())
# Out:
# lat         0
# lng         0
# gid         0
# entidad     0
# objeto      0
# fna         0
# gna         0
# nam         0
# tap         0
# jap         0
# caa         0
# fdc        59
# sag         1
# area        0
# dtype: int64

# %% [markdown]
# 5. Frecuencias de variables categóricas
# Para al menos tres variables categóricas, calcule sus frecuencias. Identifique la categoría más frecuente.

# %% [markdown]
# resp. esta es la manera de calcular la frecuencia de una variable

# %% [raw]
# frecuencia de tap:

# %%
filtr1 = area["tap"].value_counts()
print(filtr1)
# Out:
# tap
# 2    284
# 1     95
# 3     12
# 0      4
# Name: count, dtype: int64

# %% [markdown]
# aqui el tipo de tap [tipo de area] mas frecuente es tipo 2 [reserva]

# %%
frecuencia de jap:

# %%
filtr1 = area["jap"].value_counts()
print(filtr1)
# Out:
# jap
#  3    222
#  2    103
#  5     33
#  4     32
#  0      3
# -1      2
# Name: count, dtype: int64

# %% [markdown]
# aqui el tipo jap [jurisdiccion] mas frecuente es 3 [provincial]

# %% [raw]
# frecuencia de caa:

# %%
filtr1 = area["caa"].value_counts()
print(filtr1)
# Out:
# caa
#  17    353
#  3      34
#  0       4
# -1       4
# Name: count, dtype: int64

# %% [markdown]
# aqui el tipo de caa [autoridad responsable] es 17

# %% [markdown]
# 6. Filtros básicos
# Realice al menos dos filtros diferentes para obtener subconjuntos de datos según condiciones lógicas (por ejemplo, registros de una región específica, valores superiores a un umbral, etc.). Muestre los tamaños de los subconjuntos.

# %% [markdown]
# Parte 2 – Preguntas de análisis (10 preguntas)

# %%
import plotly.express as px

# %%
import folium

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in ./env/lib/python3.13/site-packages (7.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in ./env/lib/python3.13/site-packages (from plotly) (2.25.0)
# Requirement already satisfied: packaging in ./env/lib/python3.13/site-packages (from plotly) (26.3)

# %% [markdown]
# pio.renderers.default = "notebook"

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in ./env/lib/python3.13/site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in ./env/lib/python3.13/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in ./env/lib/python3.13/site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in ./env/lib/python3.13/site-packages (from folium) (2.5.2)
# Requirement already satisfied: requests in ./env/lib/python3.13/site-packages (from folium) (2.34.2)
# Requirement already satisfied: xyzservices in ./env/lib/python3.13/site-packages (from folium) (2026.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./env/lib/python3.13/site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./env/lib/python3.13/site-packages (from requests->folium) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.13/site-packages (from requests->folium) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in ./env/lib/python3.13/site-packages (from requests->folium) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./env/lib/python3.13/site-packages (from requests->folium) (2026.7.22)

# %% [markdown]
# ---Filtrar: condición de una columna, por más de una columna.

# %% [markdown]
#        preguntas:

# %% [markdown]
# 1.calculo: de todas las areas de jurisdiccion jap, cual es su subtipo mas frecuente?

# %% [markdown]
#        respuesta:

# %%
filtr2 = area["jap"].value_counts()
print(filtr2)
# Out:
# jap
#  3    222
#  2    103
#  5     33
#  4     32
#  0      3
# -1      2
# Name: count, dtype: int64

# %% [markdown]
# explicacion: con una variable, se filtro por jap y sobre ella se hizo una value_counts

# %% [markdown]
# 2.calculo: ¿cual es el valor maximo total de las longitudes y latitudes?

# %% [markdown]
#       respuesta:

# %%
filtr1 = area["lat"].max()
filtr2 = area["lng"].max()
print(filtr1)
print(filtr2)
# Out:
# -22.1586842099999
# -53.7909397257891

# %% [markdown]
# explicacion: se utilizaron por dos filtros diferentes (uno latitud y otro longitud)

# %% [markdown]
# 1.filtro:¿Cuál es el área promedio de los Parques Nacionales (tap == 1 y jap == 2)? ¿Y de las Reservas Provinciales (tap == 2 y jap == 3)?

# %% [markdown]
#       Resp:

# %%
filtr = area[(area["tap"] == 1)&(area.jap == 2)]
filtr.area.mean()
# Out:
# np.float64(913448.268292683)

# %%
filtr = area[(area["tap"] == 2)&(area.jap == 3)]
filtr.area.mean()
# Out:
# np.float64(1331852.903030303)

# %% [markdown]
# explicacion: aqui se utiliza "&" para adjuntar dos  instancias y filtrarlas como una sola variable

# %% [markdown]
# 2.filtro: filtrar todas las areas nacionales (tap == 2) que sean menores a la latitud -35

# %%
filtr = area[area["tap"] == 2]
filtr2 = filtr["lat"].mean()
print(filtr2)
# Out:
# -35.01059728459855

# %%
filtr1 = area[area["lat"] < -35]
filtr2 = filtr1[filtr1["tap"] == 2]
print(filtr2.value_counts())
# Out:
# lat         lng         gid  entidad  objeto          fna                                                                         gna                                              nam                                  tap  jap  caa  fdc                                                   sag  area
# -53.546655  -68.041297  362  falso    Área protegida  Sitio RAMSAR y Reserva Hemisférica Costa Atlántica de Tierra del Fuego      Sitio RAMSAR y Reserva Hemisférica               Costa Atlántica de Tierra del Fuego  2    2    17   SIB/IGN/Ley Provincial Nº 415/1998                    IGN  762166    1
# -39.039733  -61.386494  1    falso    Área protegida  Reserva Geológica, Paleontológica y Arqueológica Pehuen Có - Monte Hermoso  Reserva Geológica, Paleontológica y Arqueológic  Pehuen Có - Monte Hermoso            2    3    17   SIB/IGN/Ley Provincial Nº 13.394                      IGN  572244    1
# -38.810728  -62.270099  2    falso    Área protegida  Reserva Natural Integral Islote de la Gaviota Cangrejera                    Reserva Natural Integral                         Islote de la Gaviota Cangrejera      2    3    17   SIB/IGN/Decreto Provincial Nº 469                     IGN  2925      1
# -38.932023  -60.584677  3    falso    Área protegida  Reserva Natural Provincial de Uso Múltiple Arroyo Los Gauchos               Reserva Natural Provincial de Uso Múltiple       Arroyo Los Gauchos                   2    3    17   SIB/IGN/Decreto Provincial Nº 469/2011                IGN  7413      1
# -42.880414  -71.586047  343  falso    Área protegida  Área Natural Protegida Los Alerces                                          Area Natural Protegida                           Los Alerces Reserva Nacional         2    3    17   MAyDS                                                 IGN  714007    1
#                                                                                                                                                                                                                                                                                                            ..
# -37.644799  -57.382509  380  falso    Área protegida  Reserva Natural Provincial de Uso Múltiple Mar Chiquita                     Reserva Natural Provincial de Uso Múltiple       Mar Chiquita                         2    3    17   SIB/IGN/OPDS                                          IGN  90020     1
# -37.712611  -57.406225  382  falso    Área protegida  Reserva Natural de la Defensa Mar Chiquita - Dragones de Malvinas           Reserva Natural de la Defensa                    Mar Chiquita - Dragones de Malvinas  2    2    17   SIB/IGN/Protocolo adicional Nº 04/2009                IGN  18615     1
# -37.622410  -57.345979  383  falso    Área protegida  Reserva de Biósfera Parque Atlántico Mar Chiquita                           Reserva de Biósfera                              Parque Atlántico Mar Chiquita        2    3    17   SIB/IGN/Ordenanza Municipal Mar Chiquita Nº 169/1990  IGN  286255    1
# -52.347352  -68.395760  384  falso    Área protegida  Reserva Provincial Cabo Vírgenes                                            Reserva Provincial                               Cabo Vírgenes                        2    3    17   SIB/IGN/Ley Provincial Nº 1.806                       IGN  26174     1
# -51.577348  -69.029135  385  falso    Área protegida  Área de Uso Científico Bajo Protección Especial Isla Deseada                Área de Uso Científico Bajo Protección Especial  Isla Deseada                         2    3    17   SIB/IGN/Disposición Nº 7/1990                         IGN  244       1
# Name: count, Length: 105, dtype: int64

# %% [markdown]
# explicacion: utilizamos dos filtros, una variable para establecer el punto de salida para comenzar a filtrar (filtr1) y otro que establece el tipo jap 2 por el que se va a filtrar.

# %% [markdown]
# 3.filtro: ¿cual es la area protegida cuyo codigo gid es 262?

# %% [markdown]
#          Resp:

# %%
filtr1 = area[area["gid"] == 262]
filtr2 = filtr1["nam"]
print(filtr2)
# Out:
# 268    del Sistema Domuyo
# Name: nam, dtype: str

# %% [markdown]
# explicacion: se filtro primero con una variable que almacena el codigo gid.
# luego con otra variable se filtro por el nombre del area.

# %% [markdown]
# ---Gráficos: torta, barra(datos ordenados), línea

# %% [markdown]
#     preguntas:

# %% [markdown]
# 1.Gráfico: crear un grafico potly bar que identifique todos los tipos jurisdiccion (tap) ¿cual es el tipo de area de jurisdiccion mas frecuente?

# %% [markdown]
#      Resp:

# %%
filtr3 = area["tap"].value_counts()
fig = px.bar(
    data_frame = filtr3, x = filtr3.index, y = filtr3.values, title = "grafico con la frecuencia de los subtipo jurisdccion")
fig.show()

# %% [markdown]
# explicacion: aqui se utilizo la herramienta potly bar, filtrando por tap, para mostrar cual area tipo jurisdiccion es mas frecuente. (x = valor y = frecuencia)

# %% [markdown]
# 2.grafico: ¿Cuál es el tipo de área protegida (tap) mayor a la longitud (lng) promedio mas frecuente?

# %% [markdown]
#           Resp:

# %%
filtr2 = area[area["lng"] > -63]
filtr3 = filtr2["tap"]
pig = px.pie(
    data_frame = filtr3, values = filtr3.index, names = filtr3.values, title = "grafico de jurisdicciones tap mayores al promedio")
pig.show()

# %% [markdown]
# explicacion: aqui se utilizo la herramienta poylt pie, se filtro por dos variables distintas; una que guardaba el promedio de longitud lng, y otra que lo filtraba por tipo tap.

# %% [markdown]
# 3.grafico: utilizando potly line; queremos generar un grafico que muestre la latitud de todas las areas protegidas; parques nacionales ("tap 1" y "jap 2") menores al promedio ¿cual es el parque nacional con menos latitud?

# %% [markdown]
#       Resp:

# %%
filtr1 = area[(area["tap"] == 1)&(area.jap == 2)]
filtr2 = filtr1[filtr1["lat"] > -34]
filtr3 = filtr2["nam"]
dig = px.bar(
    filtr3, y = filtr3.values, x = filtr3.index, title = "grafico de todos los parques nacionales protegidos, de menor latitud hasta mayor")
dig.show()

# %% [markdown]
# Explicacion: utilizando la funcion "&" para adjuntar dos instancias como una sola variable (parques naciones = tap 1 y jap 2) y filtrando luego por latitud nombre, con potly line creamos nuestro grafico.

# %% [markdown]
# 1mapa:filtrar visualmente con un mapa todos las areas protegidas tipo parque(tap = 1)

# %% [markdown]
#            resp:

# %%
attr = (
    '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
    'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
)

tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'

mapa = folium.Map(
    location=(-33.457606, -65.346857),
    control_scale=True,
    zoom_start=5,
)
folium.TileLayer(
        tiles=tiles,
        attr=attr,
        name="Argenmap IGN",
        tms=True
    ).add_to(mapa)

filtr = area[area["tap"] == 1]

for _, fila in filtr.iterrows():

    folium.Marker(
        location=[fila["lat"], fila["lng"]],
        popup=fila["nam"],
        category_col="Parque"
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d3a2478542d87084566b60330e8e0e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d3a2478542d87084566b60330e8e0e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d3a2478542d87084566b60330e8e0e1 = L.map(
#                 &quot;map_5d3a2478542d87084566b60330e8e0e1&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_5d3a2478542d87084566b60330e8e0e1);
#
#
#
#
#
#             var tile_layer_3db31a06eb7b87c0f0c73060d11b3243 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3db31a06eb7b87c0f0c73060d11b3243.addTo(map_5d3a2478542d87084566b60330e8e0e1);
#
#
#             var tile_layer_14a98928ad5bae0801ef24afceade2cf = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: true,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_14a98928ad5bae0801ef24afceade2cf.addTo(map_5d3a2478542d87084566b60330e8e0e1);
#
#
#             var marker_a60cdeb115c81318c42cf2ad97a69f8a = L.marker(
#                 [-26.0317796969999, -54.4187433829442],
#                 {
#   &quot;categoryCol&quot;: &quot;Parque&quot;,
# }
#             ).addTo(map_5d3a2478542d87084566b60330e8e0e1);
#
#
#         var popup_e4c7940554b3137a680a202a6789fb0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b61aee027a1b32667a27746d4e2e5431 = $(`&lt;div id=&quot;html_b61aee027a1b32667a27746d4e2e5431&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lote C Huerto Municipal&lt;/div&gt;`)[0];
#                 popup_e4c7940554b3137a680a202a6789fb0c.setContent(html_b61aee027a1b32667a27746d4e2e5431);
#
#
#
#         marker_a60cdeb115c81318c42cf2ad97a69f8a.bindPopup(popup_e4c7940554b3137a680a202a6789fb0c)
#         ;
#
#
#
#
#             var marker_93911ddf019a96a52ceb31c98e3feb53 = L.marker(
#                 [-26.4022577179999, -65.680992151561],
#                 {
#   &quot;categoryCol&quot;: &quot;Parque&quot;,
# }
#             ).addTo(map_5d3a2478542d87084566b60330e8e0e1);
#
#
#         var popup_e36d117f3993fa10a48470eac413bc79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78deb7fc69e539bcf4f7b772c6128547 = $(`&lt;div id=&quot;html_78deb7fc69e539bcf4f7b772c6128547&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cumbres Calchaquíes&lt;/div&gt;`)[0];
#                 popup_e36d117f3993fa10a48470eac413bc79.setContent(html_78deb7fc69e539bcf4f7b772c6128547);
#
#
#
#         marker_93911ddf019a96a52ceb31c98e3feb53.bindPopup(popup_e36d117f3993fa10a48470eac413bc79)
#         ;
#
#
#
#
#             var marker_fd51f51b2d5a68fd659fbd11149f486a = L.marker(
#                 [-47.92545844, -72.3175139920585],
#                 {
#   &quot;categoryCol&quot;: &quot;Parque&quot;,
# }
#             ).addTo(map_5d3a2478542d87084566b60330e8e0e1);
#
#
#         var popup_ef47d41f260500aa0f40b5de957cd89e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc7727a98eac689acd23e1e6e08c2fa9 = $(`&lt;div id=&quot;html_bc7727a98eac689acd23e1e6e08c2fa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perito Moreno&lt;/div&gt;`)[0];
#                 popup_ef47d41f260500aa0f40b5de957cd89e.setContent(html_bc7727a98eac689acd23e1e6e08c2fa9);
#
#
#
#         marker_fd51f51b2d5a68fd659fbd11149f486a.bindPopup(popup_ef47d41f260500aa0f40b5de957cd89e)
#         ;
#
#
#
#
#             var marker_c8f20db47af17f4773455b525703fab5 = L.marker(
#                 [-50.3372270369999, -69.0171115664486],
#                 {
#   &quot;categoryCol&quot;: &quot;Parque&quot;,
# }
#             ).addTo(map_5d3a2478542d87084566b60330e8e0e1);
#
#
#         var popup_5fa8e2411c72d5326fd0b0b3dd88078b = L.popup({

# %% [markdown]
# explicacion: se establecio una variable con folium.map (mapa1 = folium.map("atributos")), entonces map1 es la variable contiene el mapa que vamos a utilizar.
# luego se filtro por tap == 1, utilizando una iteracion for y folium.marker (aqui se establecio la latitud y longitud, y popup los nombres por fila), añadiendose finalmente a nuestra variable mapa.

# %% [markdown]
# 2mapa:filtrar y diferenciar por color todas las areas protegidas tipo area parque(tap = 1) y jurisdiccion provincial (jap = 3)

# %% [markdown]
#         resp:

# %%
attr = (
    '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
    'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
)

tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'

filtr1 = area[area["tap"] == 1]

filtr2 = area[area["jap"] == 3]

mapa = folium.Map(
    location=(-33.457606, -65.346857),
    control_scale=True,
    zoom_start=5,
    tiles="OpenStreetMap",

)

folium.TileLayer(
        tiles=tiles,
        attr=attr,
        name="Argenmap IGN",
        tms=True
    ).add_to(mapa)

for _, fila in filtr1.iterrows():

    folium.CircleMarker(
        location=[fila["lat"], fila["lng"]],
        radius=6,
        color="red",
        fill=True,
        fill_color="red",
        popup=fila["nam"]
    ).add_to(mapa)

for _, fila in filtr2.iterrows():

    folium.CircleMarker(
        location=[fila["lat"], fila["lng"]],
        radius=6,
        color="blue",
        fill=True,
        fill_color="blue",
        popup=fila["nam"]
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c4da9144230b97534a407b01af45c47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c4da9144230b97534a407b01af45c47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c4da9144230b97534a407b01af45c47 = L.map(
#                 &quot;map_3c4da9144230b97534a407b01af45c47&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_3c4da9144230b97534a407b01af45c47);
#
#
#
#
#
#             var tile_layer_2792e1094d90f89a3fe8f04e54741228 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2792e1094d90f89a3fe8f04e54741228.addTo(map_3c4da9144230b97534a407b01af45c47);
#
#
#             var tile_layer_298244e3d9dfcd6bb2088e9216d51cf8 = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: true,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_298244e3d9dfcd6bb2088e9216d51cf8.addTo(map_3c4da9144230b97534a407b01af45c47);
#
#
#             var circle_marker_0322e860d8ee738064dcec9bc71294fe = L.circleMarker(
#                 [-26.0317796969999, -54.4187433829442],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3c4da9144230b97534a407b01af45c47);
#
#
#         var popup_91cd05be8275bd3b4258448a2dec41bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe1f79e4db9fd18042f90eeec8a8fdd3 = $(`&lt;div id=&quot;html_fe1f79e4db9fd18042f90eeec8a8fdd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lote C Huerto Municipal&lt;/div&gt;`)[0];
#                 popup_91cd05be8275bd3b4258448a2dec41bb.setContent(html_fe1f79e4db9fd18042f90eeec8a8fdd3);
#
#
#
#         circle_marker_0322e860d8ee738064dcec9bc71294fe.bindPopup(popup_91cd05be8275bd3b4258448a2dec41bb)
#         ;
#
#
#
#
#             var circle_marker_89b0ff8c7356d9b90f955f4c7ac94fda = L.circleMarker(
#                 [-26.4022577179999, -65.680992151561],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3c4da9144230b97534a407b01af45c47);
#
#
#         var popup_6b1d00ed59e204cde8e026ea91375d12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0e0dde8708a5a32ebe3c9baf646281d = $(`&lt;div id=&quot;html_b0e0dde8708a5a32ebe3c9baf646281d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cumbres Calchaquíes&lt;/div&gt;`)[0];
#                 popup_6b1d00ed59e204cde8e026ea91375d12.setContent(html_b0e0dde8708a5a32ebe3c9baf646281d);
#
#
#
#         circle_marker_89b0ff8c7356d9b90f955f4c7ac94fda.bindPopup(popup_6b1d00ed59e204cde8e026ea91375d12)
#         ;
#
#
#
#
#             var circle_marker_efb07dd58eae47c143412edee937f118 = L.circleMarker(
#                 [-47.92545844, -72.3175139920585],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&qu

# %% [markdown]
# explicacion: aqui añadi dos variables, cada una filtrando tap = 1 y jap = 3.
#     cada folium.circlemarker representa la forma que se filtraran por color su variable correspondiente en el mapa.
