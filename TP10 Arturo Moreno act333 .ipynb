# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.5-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.5.2-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 22.7 MB/s eta 0:00:001m22.4 MB/s eta 0:00:01
# Downloading numpy-2.5.2-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 47.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: numpy, pandas
# Successfully installed numpy-2.5.2 pandas-3.0.5

# %% [markdown]
# Parte 1 – Análisis básico del dataset (10 puntos)

# %% [markdown]
# 1. Carga y exploración inicial
# Cargue el dataset y muestre sus primeras filas. Indique el número de filas y columnas.

# %% [markdown]
# Resp: aqui esta el codigo para mostrar las filas y columnas

# %%
area = pd.read_csv("area_protegida.csv")

# %%
print("Primeras 10 filas:")
print(area.head(10))
# Out:
# Primeras 10 filas:
#          lat        lng  gid entidad          objeto  \
# 0 -53.546655 -68.041297  362   falso  Área protegida
# 1 -31.404445 -64.357709  157   falso  Área protegida
# 2 -32.245004 -60.734423  169   falso  Área protegida
# 3 -26.031780 -54.418743   47   falso  Área protegida
# 4 -26.402258 -65.680992  206   falso  Área protegida
# 5 -27.630853 -67.275597  213   falso  Área protegida
# 6 -33.804530 -59.291954   99   falso  Área protegida
# 7 -47.925458 -72.317514  223   falso  Área protegida
# 8 -50.337227 -69.017112  230   falso  Área protegida
# 9 -27.474382 -55.001868   65   falso  Área protegida
#
#                                                  fna  \
# 0  Sitio RAMSAR y Reserva Hemisférica Costa Atlán...
# 1            Reserva Natural de la Defensa La Calera
# 2                      Sitio Ramsar Delta del Parana
# 3   Parque Natural Municipal Lote C Huerto Municipal
# 4              Parque Provincial Cumbres Calchaquíes
# 5            Area Natural Protegida Sierras de Belén
# 6  Reserva Natural Objetivo Definido Educativo Pa...
# 7                      Parque Nacional Perito Moreno
# 8                         Parque Nacional Monte León
# 9                   Reserva Privada Ingeniero Barney
#
#                                            gna  \
# 0           Sitio RAMSAR y Reserva Hemisférica
# 1                Reserva Natural de la Defensa
# 2                                 Sitio Ramsar
# 3                     Parque Natural Municipal
# 4                            Parque Provincial
# 5                       Area Natural Protegida
# 6  Reserva Natural Objetivo Definido Educativo
# 7                              Parque Nacional
# 8                              Parque Nacional
# 9                              Reserva Privada
#
#                                    nam  tap  jap  caa  \
# 0  Costa Atlántica de Tierra del Fuego    2    2   17
# 1                            La Calera    2    2   17
# 2                     Delta del Parana    2    2   17
# 3              Lote C Huerto Municipal    1    4   17
# 4                  Cumbres Calchaquíes    1    3   17
# 5                     Sierras de Belén    2    3   17
# 6                         Paraná Guazú    2    4   17
# 7                        Perito Moreno    1    2   17
# 8                           Monte León    1    2   17
# 9                     Ingeniero Barney    2    5    3
#
#                                         fdc    sag     area
# 0        SIB/IGN/Ley Provincial Nº 415/1998    IGN   762166
# 1    SIB/IGN/Protocolo adicional Nº 05/2009    IGN   136225
# 2                                       NaN  MAyDS  2430979
# 3              SIB/IGN/Disposición Nº 45/95    IGN      955
# 4                                       NaN    IGN   706222
# 5                                       NaN  MAyDS   392087
# 6                                       NaN  MAyDS     7541
# 7  SIB/IGN/Decreto Nacional Nº 105.433/1937    IGN   953034
# 8       SIB/IGN/Ley Nacional Nº 25.945/2004    IGN   562692
# 9     SIB/IGN/Decreto Provincial Nº 07/2000    IGN      500

# %% [markdown]
# utilizamos shape para saber el numero de filas y columnas:

# %%
print(area.shape)
# Out:
# (395, 14)

# %% [markdown]
# 2. Estructura y tipos de datos
# Identifique el tipo de dato de cada columna (numérico, categórico, fecha, geográfico, etc.) y presente un resumen de los tipos.

# %% [markdown]
# esto se puede entender con mejor facilidad utilizando Dtypes

# %%
print("Primeras 10 filas:")
print(area.dtypes)
# Out:
# Primeras 10 filas:
# lat        float64
# lng        float64
# gid          int64
# entidad        str
# objeto         str
# fna            str
# gna            str
# nam            str
# tap          int64
# jap          int64
# caa          int64
# fdc            str
# sag            str
# area         int64
# dtype: object

# %% [markdown]
# resumiendo los tipos:

# %% [markdown]
# lat ing: corresponden a un tipo de dato geografico

# %% [markdown]
# gid: es un identificador de grupo numerico

# %% [markdown]
# entidad: reconoce un lugar como parte del dataset

# %% [markdown]
# objeto: identifica una zona como parte de las areas protegidas

# %% [markdown]
# fna: es la firma de nombre geografico (nombre completo)

# %% [markdown]
# gna: significa genero del nombre geografico (termino generico)

# %% [markdown]
# nam: nombre geografico generico (termino especifico)

# %% [markdown]
# tap: tipo de area

# %% [markdown]
# jap: jurisdiccion

# %% [markdown]
# caa: Clasificación de acuerdo al tipo de autoridad responsable

# %% [markdown]
# fdp: fuente de captura

# %% [markdown]
# sad: Nombre de la autoridad responsable de la información utilizada

# %%
area: identificador de area por cordenada

# %% [markdown]
# 3. Estadísticas descriptivas
# Calcule y comente las principales medidas de resumen (media, mediana, mínimo, máximo, desviación estándar) para las variables numéricas.

# %% [markdown]
# resp: calculo y resumen numerico de longitud (lng)

# %% [markdown]
# con max se calcula el valor maximo

# %%
print(area["lng"].max())
# Out:
# -53.7909397257891

# %% [markdown]
# con min se calcula el valor minimo

# %%
print(area["lng"].min())
# Out:
# -73.402908018618

# %% [markdown]
# con mean se calcula el promedio

# %%
print(area["lng"].mean())
# Out:
# -63.44387137479367

# %% [markdown]
# con std se puede calcula la desviacion estandar

# %%
area["lng"].std()
# Out:
# np.float64(5.700540091735373)

# %% [markdown]
# 4. Valores nulos
# Detecte la cantidad de valores faltantes por columna y proponga una estrategia para tratarlos (eliminación, imputación, etc.). Justifique su decisión.

# %% [markdown]
# resp. asi se obtienen los valores nulos

# %%
print(area.isnull().sum())
# Out:
# lat         0
# lng         0
# gid         0
# entidad     0
# objeto      0
# fna         0
# gna         0
# nam         0
# tap         0
# jap         0
# caa         0
# fdc        59
# sag         1
# area        0
# dtype: int64

# %% [markdown]
# 5. Frecuencias de variables categóricas
# Para al menos tres variables categóricas, calcule sus frecuencias. Identifique la categoría más frecuente.

# %% [markdown]
# resp. esta es la manera de calcular la frecuencia de una variable

# %% [raw]
# frecuencia de tap:

# %%
filtr1 = area["tap"].value_counts()
print(filtr1)
# Out:
# tap
# 2    284
# 1     95
# 3     12
# 0      4
# Name: count, dtype: int64

# %% [markdown]
# aqui el tipo de tap [tipo de area] mas frecuente es tipo 2 [reserva]

# %%
frecuencia de jap:

# %%
filtr1 = area["jap"].value_counts()
print(filtr1)
# Out:
# jap
#  3    222
#  2    103
#  5     33
#  4     32
#  0      3
# -1      2
# Name: count, dtype: int64

# %% [markdown]
# aqui el tipo jap [jurisdiccion] mas frecuente es 3 [provincial]

# %% [raw]
# frecuencia de caa:

# %%
filtr1 = area["caa"].value_counts()
print(filtr1)
# Out:
# caa
#  17    353
#  3      34
#  0       4
# -1       4
# Name: count, dtype: int64

# %% [markdown]
# aqui el tipo de caa [autoridad responsable] es 17

# %% [markdown]
# 6. Filtros básicos
# Realice al menos dos filtros diferentes para obtener subconjuntos de datos según condiciones lógicas (por ejemplo, registros de una región específica, valores superiores a un umbral, etc.). Muestre los tamaños de los subconjuntos.

# %% [markdown]
# Parte 2 – Preguntas de análisis (10 preguntas)

# %%
import plotly.express as px

# %%
import folium

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in C:\Users\Pcstore\AppData\Local\Programs\Python\Python312\Lib\site-packages (6.9.0)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\Pcstore\AppData\Local\Programs\Python\Python312\Lib\site-packages (from plotly) (2.24.0)
# Requirement already satisfied: packaging in C:\Users\Pcstore\AppData\Local\Programs\Python\Python312\Lib\site-packages (from plotly) (26.2)

# %% [markdown]
# ---Filtrar: condición de una columna, por más de una columna.

# %% [markdown]
#        preguntas:

# %% [markdown]
# 1.filtro:¿Cuál es el área promedio de los Parques Nacionales (tap == 1 y jap == 2)? ¿Y de las Reservas Provinciales (tap == 2 y jap == 3)?

# %% [markdown]
#       Resp:

# %%
filtr = area[(area["tap"] == 1)&(area.jap == 2)]
filtr.area.mean()
# Out:
# np.float64(913448.268292683)

# %%
filtr = area[(area["tap"] == 2)&(area.jap == 3)]
filtr.area.mean()
# Out:
# np.float64(1331852.903030303)

# %% [markdown]
# explicacion: aqui se utiliza "&" para adjuntar dos  instancias y filtrarlas como una sola variable

# %% [markdown]
# ---Gráficos: torta, barra(datos ordenados), línea

# %% [markdown]
#     preguntas:

# %% [markdown]
# 1.Gráfico: crear un grafico potly bar que identifique todos los tipos jurisdiccion (tap) ¿cual es el tipo de area de jurisdiccion mas frecuente?

# %% [markdown]
#      Resp:

# %%
filtr3 = area["tap"].value_counts()
fig = px.bar(
    data_frame = filtr3, x = filtr3.index, y = filtr3.values, title = "titulo")
fig.show()

# %% [markdown]
# explicacion: aqui se utilizo la herramienta potly bar, filtrando por tap, para mostrar cual area tipo jurisdiccion es mas frecuente. (x = valor y = frecuencia)

# %% [markdown]
# 2.grafico: ¿Cuál es el tipo de área protegida (tap) mayor a la longitud (lng) promedio mas frecuente?

# %% [markdown]
#           Resp:

# %%
filtr2 = area[area["lng"] > -63]
filtr3 = filtr2["tap"]
pig = px.pie(
    data_frame = filtr3, values = filtr3.index, names = filtr3.values, title = "grafico de jurisdicciones tap mayores al promedio")
pig.show()

# %%
explicacion: aqui se utilizo la herramienta poylt pie, se filtro por dos variables distintas; una que guardaba el promedio de longitud lng, y otra que lo filtraba por tipo tap.

# %% [markdown]
# 3.grafico: utilizando potly line; queremos generar un grafico que muestre la latitud de todas las areas protegidas; parques nacionales ("tap 1" y "jap 2") menores al promedio ¿cual es el parque nacional con menos latitud?

# %% [markdown]
#       Resp:

# %%
filtr1 = area[(area["tap"] == 1)&(area.jap == 2)]
filtr2 = filtr1[filtr1["lat"] < -34]
filtr3 = filtr2["nam"]
dig = px.bar(
    filtr3, y = filtr3.values, x = filtr3.index, title = "grafico de todos los parques nacionales protegidos, de menor latitud hasta mayor")
dig.show()

# %% [markdown]
# Explicacion: utilizando la funcion "&" para adjuntar dos instancias como una sola variable (parques naciones = tap 1 y jap 2) y filtrando luego por latitud nombre, con potly line creamos nuestro grafico.

# %% [markdown]
# 1mapa:filtrar visualmente con un mapa todos las areas protegidas tipo parque(tap = 1)

# %% [markdown]
#            resp:

# %%
mapa = folium.Map(
    location=(-33.457606, -65.346857),
    control_scale=True,
    zoom_start=5,
    tiles="OpenStreetMap",

)

filtr = area[area["tap"] == 1]

for _, fila in filtr.iterrows():

    folium.Marker(
        location=[fila["lat"], fila["lng"]],
        popup=fila["nam"],
        category_col="Parque"
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f34f64f1c962b46e9b714cf54702fec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f34f64f1c962b46e9b714cf54702fec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f34f64f1c962b46e9b714cf54702fec = L.map(
#                 &quot;map_9f34f64f1c962b46e9b714cf54702fec&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_9f34f64f1c962b46e9b714cf54702fec);
#
#
#
#
#
#             var tile_layer_6c6e7c89a931af534c8a3598b74191a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6c6e7c89a931af534c8a3598b74191a2.addTo(map_9f34f64f1c962b46e9b714cf54702fec);
#
#
#             var marker_f1dd9e6019f5ca9b84c8cdb9e45468a0 = L.marker(
#                 [-26.0317796969999, -54.4187433829442],
#                 {
#   &quot;categoryCol&quot;: &quot;Parque&quot;,
# }
#             ).addTo(map_9f34f64f1c962b46e9b714cf54702fec);
#
#
#         var popup_c49655c0ca7f6c3d751b07c0022131c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1389aeab9e9ab6d7fb211e5e2cbd616 = $(`&lt;div id=&quot;html_f1389aeab9e9ab6d7fb211e5e2cbd616&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lote C Huerto Municipal&lt;/div&gt;`)[0];
#                 popup_c49655c0ca7f6c3d751b07c0022131c7.setContent(html_f1389aeab9e9ab6d7fb211e5e2cbd616);
#
#
#
#         marker_f1dd9e6019f5ca9b84c8cdb9e45468a0.bindPopup(popup_c49655c0ca7f6c3d751b07c0022131c7)
#         ;
#
#
#
#
#             var marker_eb85de534b52563d1b8b87ad95a6a788 = L.marker(
#                 [-26.4022577179999, -65.680992151561],
#                 {
#   &quot;categoryCol&quot;: &quot;Parque&quot;,
# }
#             ).addTo(map_9f34f64f1c962b46e9b714cf54702fec);
#
#
#         var popup_2a8f66c6072070b4a7321a70f4ac3453 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb1d4ae7ca93a9a6a3789e8f2f823b4f = $(`&lt;div id=&quot;html_bb1d4ae7ca93a9a6a3789e8f2f823b4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cumbres Calchaquíes&lt;/div&gt;`)[0];
#                 popup_2a8f66c6072070b4a7321a70f4ac3453.setContent(html_bb1d4ae7ca93a9a6a3789e8f2f823b4f);
#
#
#
#         marker_eb85de534b52563d1b8b87ad95a6a788.bindPopup(popup_2a8f66c6072070b4a7321a70f4ac3453)
#         ;
#
#
#
#
#             var marker_0ffe9dd0289f11367e5888916d14de8a = L.marker(
#                 [-47.92545844, -72.3175139920585],
#                 {
#   &quot;categoryCol&quot;: &quot;Parque&quot;,
# }
#             ).addTo(map_9f34f64f1c962b46e9b714cf54702fec);
#
#
#         var popup_dbffa5d20f03cee1a0ec3a6f9a1027be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c405e33e70f6e644208d0a846be040d = $(`&lt;div id=&quot;html_3c405e33e70f6e644208d0a846be040d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perito Moreno&lt;/div&gt;`)[0];
#                 popup_dbffa5d20f03cee1a0ec3a6f9a1027be.setContent(html_3c405e33e70f6e644208d0a846be040d);
#
#
#
#         marker_0ffe9dd0289f11367e5888916d14de8a.bindPopup(popup_dbffa5d20f03cee1a0ec3a6f9a1027be)
#         ;
#
#
#
#
#             var marker_09077d22cc569f6fe8f2f2e5ab24e166 = L.marker(
#                 [-50.3372270369999, -69.0171115664486],
#                 {
#   &quot;categoryCol&quot;: &quot;Parque&quot;,
# }
#             ).addTo(map_9f34f64f1c962b46e9b714cf54702fec);
#
#
#         var popup_3ef114b70b261bd3ac852fd6434ee1a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_542f788fd295195fbf99e604a14b4336 = $(`&lt;div id=&quot;html_542f788fd295195fbf99e604a14b4336&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Monte León&lt;/div&gt;`)[0];
#                 popup_3ef114b70b261bd3ac852fd6434ee1a4.setContent(html_542f788fd295195fbf99e604a14b4336);
#
#
#
#         marker_09077d22cc569f6fe8f2f2e5ab24e166.bindPopup(popup_3ef114b70b261bd3ac852fd6434ee1a4)
#         ;
#
#
#
#
#             var marker_e889b10974534d9af2b9720da6b27622 = L.marker(
#                 [-26.8479787945, -59.6551680999174],
#                 {
#   &quot;categoryCol&quot;: &quot;Parque&quot;,
# }
#             ).addTo(map_9f34f64f1c962b46e9b714cf54702fec);
#
#
#         var popup_d262581661ebc7c337e03b447048d31d = L.popup({
#   &quot;maxWidth&quot;: &qu

# %% [markdown]
# explicacion: se establecio una variable con folium.map (mapa1 = folium.map("atributos")), entonces map1 es la variable contiene el mapa que vamos a utilizar.
# luego se filtro por tap == 1, utilizando una iteracion for y folium.marker (aqui se establecio la latitud y longitud, y popup los nombres por fila), añadiendose finalmente a nuestra variable mapa.

# %% [markdown]
# 2mapa:filtrar y diferenciar por color todas las areas protegidas tipo area parque(tap = 1) y jurisdiccion provincial (jap = 3)

# %% [markdown]
#         resp:

# %%
filtr1 = area[area["tap"] == 1]

filtr2 = area[area["jap"] == 3]

mapa = folium.Map(
    location=(-33.457606, -65.346857),
    control_scale=True,
    zoom_start=5,
    tiles="OpenStreetMap",

)

for _, fila in filtr1.iterrows():

    folium.CircleMarker(
        location=[fila["lat"], fila["lng"]],
        radius=6,
        color="red",
        fill=True,
        fill_color="red",
        popup=fila["nam"]
    ).add_to(mapa)

for _, fila in filtr2.iterrows():

    folium.CircleMarker(
        location=[fila["lat"], fila["lng"]],
        radius=6,
        color="blue",
        fill=True,
        fill_color="blue",
        popup=fila["nam"]
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2163d624c58af8033f0857e0836d81fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2163d624c58af8033f0857e0836d81fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2163d624c58af8033f0857e0836d81fe = L.map(
#                 &quot;map_2163d624c58af8033f0857e0836d81fe&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_2163d624c58af8033f0857e0836d81fe);
#
#
#
#
#
#             var tile_layer_9246d066f1dad9a377def0b776146171 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9246d066f1dad9a377def0b776146171.addTo(map_2163d624c58af8033f0857e0836d81fe);
#
#
#             var circle_marker_8808622ea0d23f0e6184f774929a1c6c = L.circleMarker(
#                 [-26.0317796969999, -54.4187433829442],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2163d624c58af8033f0857e0836d81fe);
#
#
#         var popup_a71f88baa83412a3ddd38f09ea9f0097 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc66145dff032b80b8e4b0057ff9e817 = $(`&lt;div id=&quot;html_dc66145dff032b80b8e4b0057ff9e817&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lote C Huerto Municipal&lt;/div&gt;`)[0];
#                 popup_a71f88baa83412a3ddd38f09ea9f0097.setContent(html_dc66145dff032b80b8e4b0057ff9e817);
#
#
#
#         circle_marker_8808622ea0d23f0e6184f774929a1c6c.bindPopup(popup_a71f88baa83412a3ddd38f09ea9f0097)
#         ;
#
#
#
#
#             var circle_marker_836cc04addd3c23ffba06344973b50b9 = L.circleMarker(
#                 [-26.4022577179999, -65.680992151561],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2163d624c58af8033f0857e0836d81fe);
#
#
#         var popup_4397b84433c0f983752560a502f1451f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8b0cb7132e82c82b3d93068fef3214b = $(`&lt;div id=&quot;html_f8b0cb7132e82c82b3d93068fef3214b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cumbres Calchaquíes&lt;/div&gt;`)[0];
#                 popup_4397b84433c0f983752560a502f1451f.setContent(html_f8b0cb7132e82c82b3d93068fef3214b);
#
#
#
#         circle_marker_836cc04addd3c23ffba06344973b50b9.bindPopup(popup_4397b84433c0f983752560a502f1451f)
#         ;
#
#
#
#
#             var circle_marker_e62e7a27628f16f3df91f2514bee3634 = L.circleMarker(
#                 [-47.92545844, -72.3175139920585],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2163d624c58af8033f0857e0836d81fe);
#
#
#         var popup_ca4c9c67f539319884e1f280c5ee4a3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a09c5f2fdda71d3e0cad0535dfd19ddf = $(`&lt;div id=&quot;html_a09c5f2fdda71d3e0cad0535dfd19ddf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perito Moreno&lt;/div&gt;`)[0];
#                 popup_ca4c9c67f539319884e1f280c5ee4a3d.setContent(html_a09c5f2fdda71d3e0cad0535dfd19ddf);
#
#
#
#         circle_marker_e62e7a27628f16f3df91f2514bee3634.bindPopup(popup_ca4c9c67f5393

# %% [markdown]
# explicacion: aqui añadi dos variables, cada una filtrando tap = 1 y jap = 3.
#     cada folium.circlemarker representa la forma que se filtraran por color su variable correspondiente en el mapa.
